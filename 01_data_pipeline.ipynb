# %%
# %pip install -r data_pipeline/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 MB 66.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 93.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 89.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 124.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 91.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 158.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.3/571.3 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 114.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 110.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.5/645.5 kB 23.8 MB/s eta 0:00:00
# ...

# %%
# %restart_python

# %%
# !python -m data_pipeline.scripts.ingest_pdf
# Out:
# Processing: BLDS_2015.pdf
# Saved cleaned text to: /Volumes/workspace/default/legal_storage/cleaned/BLDS_2015.txt
# Saved chunks to: /Volumes/workspace/default/legal_storage/processed/BLDS_2015.json
# Processing: BLHS_2015_SDBS_2017_TVPL.pdf
# Saved cleaned text to: /Volumes/workspace/default/legal_storage/cleaned/BLHS_2015_SDBS_2017_TVPL.txt
# Saved chunks to: /Volumes/workspace/default/legal_storage/processed/BLHS_2015_SDBS_2017_TVPL.json
# Processing: Luat_cac_to_chuc_tin_dung.pdf
# Saved cleaned text to: /Volumes/workspace/default/legal_storage/cleaned/Luat_cac_to_chuc_tin_dung.txt
# Saved chunks to: /Volumes/workspace/default/legal_storage/processed/Luat_cac_to_chuc_tin_dung.json
# Processing: Luat_dat_dai_2024.pdf
# Saved cleaned text to: /Volumes/workspace/default/legal_storage/cleaned/Luat_dat_dai_2024.txt
# Saved chunks to: /Volumes/workspace/default/legal_storage/processed/Luat_dat_dai_2024.json
# Processing: luat_chuyen_doi_so.pdf
# ...

# %%
# !python -m data_pipeline.scripts.build_index
# Out:
# Loaded 9174 chunks.
# ...
# config_sentence_transformers.json: 100%|███████| 205/205 [00:00<00:00, 1.27MB/s]
# README.md: 24.9kB [00:00, 47.1MB/s]
# ...
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 353kB/s]
# config.json: 100%|█████████████████████████████| 672/672 [00:00<00:00, 4.36MB/s]
# model.safetensors: 100%|██████████████████████| 540M/540M [00:02<00:00, 199MB/s]
# Loading weights: 100%|██████████████████████| 199/199 [00:00<00:00, 4795.36it/s]
# tokenizer_config.json: 1.17kB [00:00, 4.43MB/s]
# added_tokens.json: 100%|██████████████████████| 22.0/22.0 [00:00<00:00, 132kB/s]
# special_tokens_map.json: 100%|█████████████████| 965/965 [00:00<00:00, 4.86MB/s]
# vocab.txt: 895kB [00:00, 94.5MB/s]
# bpe.codes: 1.14MB [00:00, 137MB/s]
# config.json: 100%|█████████████████████████████| 296/296 [00:00<00:00, 1.80MB/s]
# ...
